# %%
from sklearn.datasets import load_iris
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
dt_clf = DecisionTreeClassifier()
iris_data = load_iris()

# %%
# 학습용 테스트용 데이터 세트 분리
X_train, X_test, y_train, y_test = train_test_split(iris_data.data, iris_data.target, test_size=0.3, random_state=121)
print("X_train: ", X_train)
print('X_test: ', X_test)
print("shape of X_test", X_test.shape)
print('y_train: ', y_train)
print('y_test:', y_test)
print("shape of y_test: ", len(y_test))
# Out:
# X_train:  [[6.3 2.8 5.1 1.5]
#  [6.8 3.2 5.9 2.3]
#  [4.8 3.4 1.9 0.2]
#  [6.3 2.5 4.9 1.5]
#  [5.  3.5 1.3 0.3]
#  [5.2 3.5 1.5 0.2]
#  [4.4 3.  1.3 0.2]
#  [5.7 4.4 1.5 0.4]
#  [6.1 3.  4.6 1.4]
#  [6.7 3.  5.  1.7]
#  [5.  3.4 1.6 0.4]
#  [6.5 3.  5.2 2. ]
#  [6.7 3.3 5.7 2.5]
#  [5.  2.3 3.3 1. ]
#  [5.4 3.4 1.5 0.4]
#  [4.4 3.2 1.3 0.2]
#  [6.2 2.9 4.3 1.3]
#  [5.1 3.5 1.4 0.3]
#  [6.7 2.5 5.8 1.8]
#  [6.8 3.  5.5 2.1]
#  [4.6 3.6 1.  0.2]
#  [4.8 3.4 1.6 0.2]
#  [7.3 2.9 6.3 1.8]
#  [6.7 3.3 5.7 2.1]
#  [6.1 2.8 4.7 1.2]
#  [5.8 2.8 5.1 2.4]
#  [5.9 3.  5.1 1.8]
#  [6.3 3.3 4.7 1.6]
#  [5.4 3.  4.5 1.5]
#  [7.7 2.8 6.7 2. ]
#  [5.8 2.7 4.1 1. ]
#  [6.4 2.8 5.6 2.1]
#  [5.6 2.5 3.9 1.1]
#  [5.1 3.8 1.9 0.4]
#  [6.2 2.8 4.8 1.8]
#  [4.7 3.2 1.3 0.2]
#  [5.5 2.4 3.8 1.1]
#  [5.9 3.  4.2 1.5]
#  [7.2 3.2 6.  1.8]
#  [5.5 2.4 3.7 1. ]
#  [4.9 3.6 1.4 0.1]
#  [5.7 2.8 4.1 1.3]
#  [5.8 2.7 5.1 1.9]
#  [6.7 3.  5.2 2.3]
#  [5.7 2.5 5.  2. ]
#  [4.9 3.1 1.5 0.1]
#  [6.3 3.3 6.  2.5]
#  [5.5 4.2 1.4 0.2]
#  [6.7 3.1 5.6 2.4]
#  [7.7 3.  6.1 2.3]
#  [5.  3.2 1.2 0.2]
#  [5.1 3.5 1.4 0.2]
#  [5.6 2.8 4.9 2. ]
#  [4.3 3.  1.1 0.1]
#  [6.1 2.8 4.  1.3]
#  [6.5 3.  5.8 2.2]
#  [5.8 2.7 5.1 1.9]
#  [4.8 3.  1.4 0.1]
#  [6.1 3.  4.9 1.8]
#  [4.9 3.  1.4 0.2]
#  [6.1 2.9 4.7 1.4]
#  [5.  3.4 1.5 0.2]
#  [6.3 2.9 5.6 1.8]
#  [5.4 3.9 1.3 0.4]
#  [7.7 3.8 6.7 2.2]
#  [5.6 3.  4.1 1.3]
#  [4.8 3.  1.4 0.3]
#  [6.4 2.8 5.6 2.2]
#  [5.  3.6 1.4 0.2]
#  [5.5 3.5 1.3 0.2]
#  [6.5 3.2 5.1 2. ]
#  [4.8 3.1 1.6 0.2]
#  [6.8 2.8 4.8 1.4]
#  [7.2 3.  5.8 1.6]
#  [6.3 2.3 4.4 1.3]
#  [6.  2.2 5.  1.5]
#  [5.8 4.  1.2 0.2]
#  [5.8 2.7 3.9 1.2]
#  [6.2 2.2 4.5 1.5]
#  [6.9 3.1 5.4 2.1]
#  [5.4 3.7 1.5 0.2]
#  [7.4 2.8 6.1 1.9]
#  [6.4 3.2 4.5 1.5]
#  [6.9 3.2 5.7 2.3]
#  [5.6 2.7 4.2 1.3]
#  [6.5 3.  5.5 1.8]
#  [5.7 2.8 4.5 1.3]
#  [4.5 2.3 1.3 0.3]
#  [7.6 3.  6.6 2.1]
#  [5.1 3.7 1.5 0.4]
#  [5.1 3.4 1.5 0.2]
#  [6.6 3.  4.4 1.4]
#  [4.9 2.4 3.3 1. ]
#  [6.9 3.1 4.9 1.5]
#  [4.6 3.1 1.5 0.2]
#  [6.5 2.8 4.6 1.5]
#  [5.  2.  3.5 1. ]
#  [4.9 3.1 1.5 0.2]
#  [5.1 3.8 1.6 0.2]
#  [5.7 2.9 4.2 1.3]
#  [6.  2.7 5.1 1.6]
#  [6.7 3.1 4.4 1.4]
#  [5.7 3.  4.2 1.2]
#  [4.4 2.9 1.4 0.2]
#  [5.6 3.  4.5 1.5]]
# X_test:  [[7.  3.2 4.7 1.4]
#  [6.2 3.4 5.4 2.3]
#  [6.  3.4 4.5 1.6]
#  [4.6 3.4 1.4 0.3]
#  [5.2 4.1 1.5 0.1]
#  [5.8 2.6 4.  1.2]
#  [5.6 2.9 3.6 1.3]
#  [5.7 2.6 3.5 1. ]
#  [5.2 2.7 3.9 1.4]
#  [6.9 3.1 5.1 2.3]
#  [5.9 3.2 4.8 1.8]
#  [5.5 2.3 4.  1.3]
#  [6.6 2.9 4.6 1.3]
#  [4.6 3.2 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [6.3 3.4 5.6 2.4]
#  [6.  2.2 4.  1. ]
#  [5.  3.  1.6 0.2]
#  [6.4 3.2 5.3 2.3]
#  [5.4 3.9 1.7 0.4]
#  [6.4 2.7 5.3 1.9]
#  [6.3 2.5 5.  1.9]
#  [6.  2.9 4.5 1.5]
#  [5.1 2.5 3.  1.1]
#  [5.5 2.6 4.4 1.2]
#  [5.5 2.5 4.  1.3]
#  [5.  3.3 1.4 0.2]
#  [5.1 3.3 1.7 0.5]
#  [7.9 3.8 6.4 2. ]
#  [7.1 3.  5.9 2.1]
#  [6.7 3.1 4.7 1.5]
#  [7.7 2.6 6.9 2.3]
#  [5.2 3.4 1.4 0.2]
#  [5.  3.5 1.6 0.6]
#  [6.4 2.9 4.3 1.3]
#  [7.2 3.6 6.1 2.5]
#  [5.3 3.7 1.5 0.2]
#  [5.7 3.8 1.7 0.3]
#  [5.4 3.4 1.7 0.2]
#  [6.1 2.6 5.6 1.4]
#  [6.3 2.7 4.9 1.8]
#  [6.  3.  4.8 1.8]
#  [6.4 3.1 5.5 1.8]
#  [5.1 3.8 1.5 0.3]
#  [4.9 2.5 4.5 1.7]]
# shape of X_test (45, 4)
# y_train:  [2 2 0 1 0 0 0 0 1 1 0 2 2 1 0 0 1 0 2 2 0 0 2 2 1 2 2 1 1 2 1 2 1 0 2 0 1
#  1 2 1 0 1 2 2 2 0 2 0 2 2 0 0 2 0 1 2 2 0 2 0 1 0 2 0 2 1 0 2 0 0 2 0 1 2
#  1 2 0 1 1 2 0 2 1 2 1 2 1 0 2 0 0 1 1 1 0 1 1 0 0 1 1 1 1 0 1]
# y_test: [1 2 1 0 0 1 1 1 1 2 1 1 1 0 0 2 1 0 2 0 2 2 1 1 1 1 0 0 2 2 1 2 0 0 1 2 0
#  0 0 2 2 2 2 0 2]
# shape of y_test:  45

# %%
# 학습
dt_clf.fit(X_train, y_train)
# 예측
pred = dt_clf.predict(X_test)
# 정확도 검증
print('예측 정확도 : {0:4f}'.format(accuracy_score(y_test, pred)))
print('y_test:' ,y_test)
print('pred  :', pred)
# Out:
# 예측 정확도 : 0.955556
# y_test: [1 2 1 0 0 1 1 1 1 2 1 1 1 0 0 2 1 0 2 0 2 2 1 1 1 1 0 0 2 2 1 2 0 0 1 2 0
#  0 0 2 2 2 2 0 2]
# pred  : [1 2 1 0 0 1 1 1 1 2 2 1 1 0 0 2 1 0 2 0 2 2 1 1 1 1 0 0 2 2 1 2 0 0 1 2 0
#  0 0 2 2 2 2 0 1]

# %% [markdown]
# ## 정리
# > 데이터 양이 150개인 붓꽃 데이터는 데이터 양이 크지 않아 전체의 30% 정도인 테스트 데이터는 45개 정도밖에 되지 않으므로 알고리즘의 예측 성능을 판단하기에는 그리 적절하지 않다!
